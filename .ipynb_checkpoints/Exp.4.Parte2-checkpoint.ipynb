# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# # Importo los datos

# %%
Si = pd.read_csv( 'Si.txt',decimal=',', header=0, names= ["temperatura_Si","energia_Si"], delim_whitespace=True )

Ge = pd.read_csv( 'Ge.txt',decimal=',', header=0, names= ["temperatura_Ge","energia_Ge"], delim_whitespace=True )

Diodo1 = pd.read_csv( 'Diodo1.txt',decimal=',', header=0, names= ["temperatura_Diodo1","energia_Diodo1"], delim_whitespace=True )

Diodo2 = pd.read_csv( 'Diodo2.txt',decimal=',', header=0, names= ["temperatura_Diodo2","energia_Diodo2"], delim_whitespace=True )

# %% [markdown]
# # Silicio

# %%
Si.plot('temperatura_Si','energia_Si', title= "Silicio")
plt.xlabel("Temperatura [k]")
plt.ylabel("Energía [eV]")
# Out:
# Text(0, 0.5, 'Energía [eV]')

# %% [markdown]
# # Germanio

# %%
Ge.plot('temperatura_Ge','energia_Ge', title= "Germanio")
plt.xlabel("Temperatura [k]")
plt.ylabel("Energía [eV]")
# Out:
# Text(0, 0.5, 'Energía [eV]')

# %% [markdown]
# # Diodo 1

# %%
Diodo1.plot('temperatura_Ge','energia_Ge', title= "Diodo 1")
plt.xlabel("Temperatura [k]")
plt.ylabel("Energía [eV]")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperatura_Ge'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-4ac9c6bbb68d> in <module>
# ----> 1 Diodo1.plot('temperatura_Ge','energia_Ge', title= "Diodo 1")
#       2 plt.xlabel("Temperatura [k]")
#       3 plt.ylabel("Energía [eV]")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     757                 if is_integer(x) and not data.columns.holds_integer():
#     758                     x = data_cols[x]
# --> 759                 elif not isinstance(data[x], ABCSeries):
#     760                     raise ValueError("x must be a label or position")
#     761                 data = data.set_index(x)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperatura_Ge'
